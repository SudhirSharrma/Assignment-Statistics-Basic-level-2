# %% [markdown]
# # <center>Assignment Basic Statistics Level 2 Set  4</center>

# %% [markdown]
# __<center>CBA: Practice Problem Set 2</center>__
# __<center>Topics: Sampling Distributions and Central Limit Theorem</center>__

# %% [markdown]
# __Question 1:__<br>
# 1.	Examine the following normal Quantile plots carefully. Which of these plots indicates that the data …<br>
# I.	Are nearly normal?<br>
# II.	Have a bimodal distribution? (One way to recognize a bimodal shape is a “gap” in the spacing of adjacent data values.)<br>
# III.	Are skewed (i.e. not symmetric) ?<br>
# IV.	Have outliers on both sides of the center?<br>
# ![image.png](attachment:image.png)

# %% [markdown]
# __Answer 1__<br>
#
# I.__Plot C__: has near normla distrbution as data is clutred on 45 degree angel in straight line. <br>
#
# II.__Plot D__: has the bimodal distiribution, as upper part is more of reflection of botton part giving way to two maximums in data  <br>
#
# III. __Plot A__: as the bottm left of Plot is in straight line but upper pat is deviating from 45 degree line. <br>
#
# IV. __Plot B__: has out liers to bot sides of reference line at aprox .01 and ar .99

# %% [markdown]
# __<hr style="border:1px solid blue">__

# %% [markdown]
# __Question 2:__
# For each of the following statements, indicate whether it is True/False. If false, explain why.<br>
#
# The manager of a warehouse monitors the volume of shipments made by the delivery team. The automated tracking system tracks every package as it moves through the facility. A sample of 25 packages is selected and weighed every day. Based on current contracts with customers, the weights should have μ = 22 lbs. and σ = 5 lbs.
#
# I. Before using a normal model for the sampling distribution of the average package weights, the manager must confirm that weights of individual packages are normally distributed.<br>
#
# II.The standard error of the daily average SE(x ̅) = 1.

# %% [markdown]
# __Answer 2__<br>
#
# I.__False__:As per Central Limit Theorem, if samples are large enough then distribution of sample means will be approximately normal even is complete data is not normal, so manager need not confirm weights of individual packages to be normaly distributed. <br>
#
# II. __True__: as standard Error is $\sigma$\SQRT(n) and from question we have: <br>
# $\sigma$= 5 and <br>
# n=25<br>
#
# Therefore: __Standard Error__: 5/SQRT(25) = 5/5 =__1__.

# %% [markdown]
# __<hr style="border:1px solid blue">__

# %% [markdown]
# __Question 3:__
# Auditors at a small community bank randomly sample 100 withdrawal transactions made during the week at an ATM machine located near the bank’s main branch. Over the past 2 years, the average withdrawal amount has been $\$50$ with a standard deviation of $\$40$. Since audit investigations are typically expensive, the auditors decide to not initiate further investigations if the mean transaction amount of the sample is between $\$45$ and $\$55$. What is the probability that in any given week, there will be an investigation?<br>
#
# A.	1.25%<br>
# B.	2.5%<br>
# C.	10.55%<br>
# D.	21.1%<br>
# E.	50%

# %% [markdown]
# __Answer 3__:__D__<br>
# In a given week the probablity of requiring an investigation in that week will be 21.1%. Please refer to calcuation below.

# %%
# to calculate probablity of Having the investigation done = 1- probablity of no ivestigation ie. 1-P(45<x<55) 
#where x is sample mean.
# to acheive this we shall calcualte Z score for P(45) and P(55)

# question we have Population SD (SD)=40 and Population mean (X)=50 and sample size (n) =100**0.5 i.e 10
SD=40
X=50

# %%
#Z score for P(45)

x=45
n=100**0.5
z45=(x-X)/(SD/n)
print("z score for P(45) is: ",z45)
# Out:
# z score for P(45) is:  -1.25

# %%
# calculating z score for P(55)
x=55
z55=(55-50)/(40/10)
print("z score for P(55) is: ",z55)
# Out:
# z score for P(55) is:  1.25

# %%
# for P(45<x<55) i.e. no investigation using z scores we use stats.norm.cdf() function
from scipy import stats
stats.norm.cdf(z55)-stats.norm.cdf(z45)
# Out:
# 0.7887004526662893

# %%
# probality of needing an investing in that week
1- (stats.norm.cdf(z55)-stats.norm.cdf(z45))
# Out:
# 0.2112995473337107

# %%
# the probablity of requiring an investigation in that week will be 21.1%

# %% [markdown]
# __<hr style="border:1px solid blue">__

# %% [markdown]
# __Question 4:__<br>
# The auditors from the above example would like to maintain the probability of investigation to 5%. Which of the following represents the minimum number transactions that they should sample if they do not want to change the thresholds of 45 and 55? Assume that the sample statistics remain unchanged.<br>
#
# A.	144<br>
# B.	150<br>
# C.	196<br>
# D.	250<br>
# E.	Not enough information<br>

# %% [markdown]
# __Answer 4__:__D__<br>
# The required sample size should be of:  246, we choose nearest value 250 (option D), Please refer to calcuation below.

# %%
# for having probability of investigation of 5% we need to find sample size, thus we need to find zcore for 95% (100-5)
# from z tables we have Z as 1.96

z=1.96

# we know Z=(sample mean - Population mean)/(population Standard deviation / sqrt(sample size))
#from question 3 we have: Population SD (SD)=40 and Population mean (X)=50
# let sample size be n

# there fore our equation becomes: n= square of ((1.96*40)/(55-40))

n= ((1.96*40)/(55-50))**2
print("The required sample size should be of: ",round(n))
# Out:
# The required sample size should be of:  246

# %% [markdown]
# __<hr style="border:1px solid blue">__

# %% [markdown]
# __Question 5:__<br>
# An educational startup that helps MBA aspirants write their essays is targeting individuals who have taken GMAT in 2012 and have expressed interest in applying to FT top 20 b-schools. There are 40000 such individuals with an average GMAT score of 720 and a standard deviation of 120. The scores are distributed between 650 and 790 with a very long and thin tail towards the higher end resulting in substantial skewness. Which of the following is likely to be true for randomly chosen samples of aspirants?<br>
#
# A.	The standard deviation of the scores within any sample will be 120. <br>
# B.	The standard deviation of the mean of across several samples will be 120. <br>
# C.	The mean score in any sample will be 720. <br>
# D.	The average of the mean across several samples will be 720. <br>
# E.	The standard deviation of the mean across several samples will be 0.60 <br>

# %% [markdown]
# __Answer 5__:__D__<br>
# As we have negiative Kurtosis with long and thing tails, there is high chance that average mean across samples will around 720.

# %% [markdown]
# __<hr style="border:1px solid blue">__
